# %% [markdown]
# ## macroeconomic predictors

# %%
import pandas as pd
import numpy as np
import datetime
import math
import matplotlib.pyplot as plt
import statistics

# %%
data = pd.read_excel('C:\\Judy\\MFE Courses\\431_Quantitative_Asset_Management\\Final_Project\\PredictorData2020.xlsx')

# %%
data
# Out:
#       yyyymm    Index        D12        E12       b/m     tbl     AAA     BAA  \
# 0     187101     4.44   0.260000   0.400000       NaN     NaN     NaN     NaN
# 1     187102     4.50   0.260000   0.400000       NaN     NaN     NaN     NaN
# 2     187103     4.61   0.260000   0.400000       NaN     NaN     NaN     NaN
# 3     187104     4.74   0.260000   0.400000       NaN     NaN     NaN     NaN
# 4     187105     4.86   0.260000   0.400000       NaN     NaN     NaN     NaN
# ...      ...      ...        ...        ...       ...     ...     ...     ...
# 1795  202008  3500.31  59.128628  98.556667  0.235975  0.0010  0.0225  0.0327
# 1796  202009  3363.00  58.851237  98.220000  0.241482  0.0011  0.0231  0.0336
# 1797  202010  3269.96  58.660440  96.856667  0.253146  0.0010  0.0235  0.0344
# 1798  202011  3621.63  58.469643  95.493333  0.226352  0.0009  0.0230  0.0330
# 1799  202012  3756.07  58.278846  94.130000  0.219195  0.0009  0.0226  0.0316
#
# ...

# %%
#data['date'] = data['yyyymm'].astype(str)
#data['Year'] = data['date'].apply(lambda x: int(x[0:4]))
#data['Month'] = data['date'].apply(lambda x: int(x[4:6]))

# %%
#Dividend Price Ratio
data['dp']= np.log(data['D12']) - np.log(data['Index'])

# %%
#Earnings-price ratio
data['ep'] = np.log(data['E12']) - np.log(data['Index'])

# %%
# Term Spread
data['tms'] = data['lty'] - data['tbl']

# %%
#default spread
data['dfy'] = data['BAA'] - data['AAA']

# %%
#data['bm'] : Book-to-Market Ratio(Given)
#data['ntis'] :net equity expansion(Given)
#data['tbl'] :Treasury-bill rate (Given)
#data[svar'] :stock variance (Given)

# %%
data[['yyyymm','dp','ep','tms','dfy','bm','ntis','tbl']].to_csv("C:\\Judy\\MFE Courses\\431_Quantitative_Asset_Management\\Final_Project\\macroeconomic.xlsx")
